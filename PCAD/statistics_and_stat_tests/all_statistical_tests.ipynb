# %%
# mean mode median
# chi-test, t-test, anova , p-value, pearson r value, r(square), errors, rss

# %%
# mode of categorial values

import numpy as np
list1 = ['apple','apple','banana','banana','banana','banana']

# %%
values, counts = np.unique(list1,return_counts=True)

# %%
values[-1]
# Out:
# np.str_('banana')

# %%
counts[-1]
# Out:
# np.int64(4)
