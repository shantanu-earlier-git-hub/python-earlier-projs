# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df =pd.read_csv("mnist_test.csv", header=0)

# %%
df_data = df.drop(['label'], axis=1)

# %%
f_image = df_data.iloc[3,:]
f_image.shape
# Out:
# (784,)

# %%
arr = np.array(f_image, dtype=np.uint8)
arr = arr.reshape(28,28)
plt.figure(figsize=(2,2))
plt.imshow(arr, interpolation='nearest',cmap='gray')
plt.savefig('digit.png', bbox_inches='tight', dpi=1200)
