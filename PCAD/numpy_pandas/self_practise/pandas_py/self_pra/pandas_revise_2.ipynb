# %%
import numpy as np
import pandas as pd

# %%
age_grp = ['teen', 'adult', 'mature', 'old']
ages = [18, 35, 50, 75]

# %%
ages = pd.Series(data=ages, name='ages')
age_grp = pd.Series(data=age_grp, name='age_grp')

# %%
ages
# Out:
# 0    18
# 1    35
# 2    50
# 3    75
# Name: ages, dtype: int64

# %%
age_grp
# Out:
# 0      teen
# 1     adult
# 2    mature
# 3       old
# Name: age_grp, dtype: object

# %%
df1= pd.DataFrame(ages)
df1
# Out:
#    ages
# 0    18
# 1    35
# 2    50
# 3    75

# %%
df2= pd.DataFrame(age_grp)
df2
# Out:
#   age_grp
# 0    teen
# 1   adult
# 2  mature
# 3     old

# %%
pd.concat(join='inner', axis=1, objs=[df1, df2])
# Out:
#    ages age_grp
# 0    18    teen
# 1    35   adult
# 2    50  mature
# 3    75     old

# %%
joined_df = df1.join(df2, how='inner')

# %%
joined_df
# Out:
#    ages age_grp
# 0    18    teen
# 1    35   adult
# 2    50  mature
# 3    75     old
