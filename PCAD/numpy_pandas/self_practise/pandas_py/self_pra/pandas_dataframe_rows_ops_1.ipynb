# %%
import numpy as np
import pandas as pd
df = pd.read_csv('../../../../data/tips.csv')

# %% [markdown]
# setting index

# %%
df = df.set_index('Payment ID')

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %% [markdown]
#     dropping a row similar to dropping a column, but the change is not permanent.
#     It needs to be Inplace or assign it to self (which is recommanded)

# %% [markdown]
# if you have string a labeled index, you cannot drop a row based on iloc[] or integer location,
# KeyNotFound error.

# %%
df.drop('Sun2959', axis=0 )
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# ...

# %%
#KeyError: '[0] not found in axis'
#df.drop(0, axis=0)

# %%
df.loc['Sun2959']
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
first_row = df.iloc[0]

# %%
first_row
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
df.tail(10)
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sat7220          15.53  3.00    Male    Yes   Sat  Dinner     2
# Sat4615          10.07  1.25    Male     No   Sat  Dinner     2
# Sat5032          12.60  1.00    Male    Yes   Sat  Dinner     2
# Sat2929          32.83  1.17    Male    Yes   Sat  Dinner     2
# Sat9777          35.83  4.67  Female     No   Sat  Dinner     3
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person       Payer Name         CC Number
# Payment ID
# Sat7220                 7.76    Tracy Douglas  4097938155941930
# Sat4615                 5.04    Sean Gonzalez  3534021246117605
# ...

# %%
first_row = df.iloc[0]
first_row
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
dict1 ={}
dict1.update(first_row.iloc[0:10])

# %%
dict1
# Out:
# {'total_bill': np.float64(16.99),
#  'tip': np.float64(1.01),
#  'sex': 'Female',
#  'smoker': 'No',
#  'day': 'Sun',
#  'time': 'Dinner',
#  'size': np.int64(2),
#  'price_per_person': np.float64(8.49),
#  'Payer Name': 'Christy Cunningham',
#  'CC Number': np.int64(3560325168603410)}

# %%
new_df = pd.DataFrame(dict1, index=['Sun2959'])
new_df
# Out:
#          total_bill   tip     sex smoker  day    time  size  price_per_person  \
# Sun2959       16.99  1.01  Female     No  Sun  Dinner     2              8.49
#
#                  Payer Name         CC Number
# Sun2959  Christy Cunningham  3560325168603410

# %%
df = df.drop('Sun2959')

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No  Sun  Dinner     4
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# Sun4458                 7.00    Travis Walters  6011812112971322
# Sun5260                11.84  Nathaniel Harris  4676137647685994
# Sun2251                 6.15      Tonya Carter  4832732618637221
# Sun9679                 6.32        Erik Smith   213140353657882

# %%
df = pd.concat([df, new_df])

# %%
df.loc[['Sun2959','Sun9679']]
# Out:
#          total_bill   tip     sex smoker  day    time  size  price_per_person  \
# Sun2959       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# Sun9679       25.29  4.71    Male     No  Sun  Dinner     4              6.32
#
#                  Payer Name         CC Number
# Sun2959  Christy Cunningham  3560325168603410
# Sun9679          Erik Smith   213140353657882

# %%
df.iloc[-10:]
# Out:
#          total_bill   tip     sex smoker   day    time  size  \
# Sat4615       10.07  1.25    Male     No   Sat  Dinner     2
# Sat5032       12.60  1.00    Male    Yes   Sat  Dinner     2
# Sat2929       32.83  1.17    Male    Yes   Sat  Dinner     2
# Sat9777       35.83  4.67  Female     No   Sat  Dinner     3
# Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17         17.82  1.75    Male     No   Sat  Dinner     2
# Thur672       18.78  3.00  Female     No  Thur  Dinner     2
# Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
#
#          price_per_person          Payer Name         CC Number
# Sat4615              5.04       Sean Gonzalez  3534021246117605
# Sat5032              6.30       Matthew Myers  3543676378973965
# Sat2929             16.42        Thomas Brown  4284722681265508
# ...
