# %%
import numpy as np
import pandas as pd

# %%
messay = pd.Series(['andrew ', ' bo;bo ', ' meu; ; ;'])

# %%
messay.str.replace(";", '').str.strip()
# Out:
# 0    andrew
# 1      bobo
# 2       meu
# dtype: object

# %%
email = "xyz@example.com"

# %%
split_email = email.split('@')
split_email
# Out:
# ['xyz', 'example.com']

# %%
print(split_email[0])
" ".join(split_email[1].split('.'))
# Out:
# xyz
# 'example com'
