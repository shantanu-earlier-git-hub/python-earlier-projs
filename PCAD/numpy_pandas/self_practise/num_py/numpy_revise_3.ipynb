# %%
import numpy as np
import pandas as pd

# %%
np.random.randint(2,4)
# Out:
# 2

# %%
students = np.random.normal(loc=125.5,scale=np.random.randint(2,4),size=10000)

# %%
import random
sample1= np.mean(random.sample(list(students),100))

# %%
sample2= np.random.choice(students,100, replace=False)

# %%
np.mean(sample2)
# Out:
# np.float64(125.73530249897918)
