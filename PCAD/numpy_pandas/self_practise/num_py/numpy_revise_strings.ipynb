# %%
import numpy as np
list1 = ['hello','world','hi','there','how','are','you']

# %%
num_list = np.arange(97,104)

# %%
num_list = np.round(num_list.astype(float),2)

# %%
num_list
# Out:
# array([ 97.,  98.,  99., 100., 101., 102., 103.])

# %%
list2 = np.array([12,23,45,67,78,89], dtype=float)

# %%
list2 = np.round(list2.astype(float),2)

# %%
list2
# Out:
# array([12., 23., 45., 67., 78., 89.])

# %%
list1 = ['hello','world','hi','there','how','are','you']
