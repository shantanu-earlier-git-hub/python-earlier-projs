# %%
list1 = [1,2,3,4,5]

# %%
list2= ['text', True, 1.2, list1, [0.0]]
list2
# Out:
# ['text', True, 1.2, [1, 2, 3, 4, 5], [0.0]]

# %%
list2.remove(1.2)
list2
# Out:
# ['text', True, [1, 2, 3, 4, 5], [0.0]]

# %%
list2.pop()
list2
# Out:
# ['text', True, [1, 2, 3, 4, 5]]

# %%
list2.append([0.0])

# %%
list2.insert(len(list2), [1,1])

# %%
list2
# Out:
# ['text', True, [1, 2, 3, 4, 5], [0.0], [1, 1]]

# %%
from typing import List
l1 :List [int]  = [10,20,30]
l2 :List [int]  = [40,50,60]

# %%
l1 + l2
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
l3 = [0] * 5
l3
# Out:
# [0, 0, 0, 0, 0]

# %%
l4 = ["nah"] * 10
l4
# Out:
# ['nah', 'nah', 'nah', 'nah', 'nah', 'nah', 'nah', 'nah', 'nah', 'nah']
